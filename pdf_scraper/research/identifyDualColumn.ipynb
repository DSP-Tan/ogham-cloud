# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import fitz
from fitz import Rect

from pdf_scraper.block_utils import identify_dual_column, get_block_text, sort_dual_column_blocks
from pdf_scraper.block_utils import is_empty_block, clean_blocks, print_block_table, get_block_table, rebox_blocks
from pdf_scraper.block_utils import preproc_blocks
from pdf_scraper.draw_utils  import get_pink_boundary, get_fill_df, in_the_pink
from pdf_scraper.draw_utils  import draw_rectangle_on_page, get_fill_colours
from pdf_scraper.line_utils  import get_line_df, print_line_table, get_all_lines

pd.set_option("display.float_format", "{:.3f}".format)

# %%
level    = "AL"
year     = 2016
fname    = f"LC002ALP100EV_{year}.pdf"
examDir  = Path.cwd().parent.parent / "Exams"  / "english" / level
pdf_file = examDir / fname


doc              = fitz.open(pdf_file)

fill_colours     = get_fill_colours(doc)

page_width       = doc[1].get_text("dict")["width"]   # This is a document wide thing doesn't need to be per page.
page_height      = doc[1].get_text("dict")["height"]  # This is a document wide thing doesn't need to be per page.


page             = doc[2]                             # Page 3
text_dict        = page.get_text("dict",sort=True)
page_drawings    = page.get_drawings()
blocks           = text_dict["blocks"]



bounding_pink    = get_pink_boundary(page_drawings, fill_colours)
clean_blocks     = preproc_blocks(blocks, bounding_pink)

pink_blocks      = [block for block in clean_blocks if in_the_pink(block["bbox"], bounding_pink) ]
pink_lines       = get_all_lines(pink_blocks)
pink_df          = get_line_df(pink_lines)

print_block_table(pink_blocks)
draw_rectangle_on_page(pdf_file, "out.pdf", 4,bounding_pink )
# Out:
# x0       x1       y0       y1       dx       dy       type  number  n_lines first_word
# --------------------------------------------------------------------------------
# 56.70    295.42   34.13    337.21   238.72   303.08   txt   0       22      It was June
# 317.22   557.68   34.13    282.01   240.46   247.88   txt   1       18      but it had
# 317.22   557.63   296.33   447.61   240.41   151.28   txt   2       15      As we worke
# 56.70    295.45   351.53   447.61   238.75   96.08    txt   3       7       For most of
# 72.66    548.15   455.52   467.67   475.49   12.15    txt   4       1       These texts
# --------------------------------------------------------------------------------

# %%
pink_centre = (bounding_pink.x0+bounding_pink.x1)/2
centre_rect = fitz.Rect(pink_centre-12, 0, pink_centre+12, page_height)
draw_rectangle_on_page(pdf_file, "out.pdf", 3,centre_rect)

# %%
pink_blocks[0]["lines"][0]
# Out:
# {'spans': [{'size': 12.0,
#    'flags': 4,
#    'bidi': 0,
#    'char_flags': 16,
#    'font': 'TimesNewRomanPSMT',
#    'color': 0,
#    'alpha': 255,
#    'ascender': 0.890999972820282,
#    'descender': -0.2160000056028366,
#    'text': 'It was June 2012, and I had come to the Globe ',
#    'origin': (56.70000076293945, 44.8197021484375),
#    'bbox': (56.70000076293945,
#     34.12770080566406,
#     295.35845947265625,
#     47.41170120239258)}],
#  'wmode': 0,
#  'dir': (1.0, 0.0),
#  'bbox': (56.70000076293945,
#   34.12770080566406,
#   295.35845947265625,
#   47.41170120239258)}

# %%
pink_df.head(100)
# Out:
#         x0      y0      x1      y1       dL  n_spans  \
# 0   56.700  34.128 295.358  47.412   13.800        1
# 1   56.700  47.928 295.382  61.212   13.800        1
# 2   56.700  61.728 295.327  75.012   13.800        1
# 3   56.700  75.528 295.343  88.812   13.800        1
# 4   56.700  89.328 295.342 102.612   13.800        3
# 5   56.700 103.128 295.358 116.412   13.800        1
# 6   56.700 116.928 295.421 130.212   13.800        1
# 7   56.700 130.728 295.332 144.012   13.800        1
# 8   56.700 144.528 295.346 157.812   13.800        1
# 9   56.700 158.328 295.368 171.612   13.800        1
# 10  56.700 172.128 295.296 185.412   13.800        1
# 11  56.700 185.928 295.339 199.212   13.800        1
# 12  56.700 199.728 295.332 213.012   13.800        1
# 13  56.700 213.528 295.326 226.812   13.800        1
# 14  56.700 227.328 295.351 240.612   13.800        1
# 15  56.700 241.128 295.392 254.412   13.800        1
# 16  56.700 254.928 295.318 268.212   13.800        1
# 17  56.700 268.728 295.303 282.012   13.800        1
# 18  56.700 282.528 295.361 295.812   13.800        1
# 19  56.700 296.328 295.370 309.612   13.800        1
# 20  56.700 310.128 295.348 323.412   13.800        1
# 21  56.700 323.928 270.007 337.212 -289.800        1
# 22 317.220  34.128 557.580  47.412   13.800        1
# 23 317.220  47.928 557.551  61.212   13.800        1
# 24 317.220  61.728 557.602  75.012   13.800        1
# 25 317.220  75.528 557.645  88.812   13.800        1
# 26 317.220  89.328 557.597 102.612   13.800        1
# 27 317.220 103.128 557.609 116.412   13.800        1
# 28 317.220 116.928 557.623 130.212   13.800        1
# 29 317.220 130.728 557.630 144.012   13.800        1
# 30 317.220 144.528 557.548 157.812   13.800        1
# 31 317.220 158.328 557.594 171.612   13.800        1
# 32 317.220 172.128 557.616 185.412   13.800        1
# 33 317.220 185.928 557.597 199.212   13.800        1
# 34 317.220 199.728 557.681 213.012   13.800        1
# 35 317.220 213.528 557.610 226.812   13.800        1
# 36 317.220 227.328 557.595 240.612   13.800        1
# 37 317.220 241.128 557.583 254.412   13.800        1
# 38 317.220 254.928 554.628 268.212   13.800        1
# 39 317.220 268.728 402.186 282.012   27.600        1
# 40 317.220 296.328 557.574 309.612   13.800        1
# 41 317.220 310.128 557.614 323.412   13.800        1
# 42 317.220 323.928 557.611 337.212   13.800        1
# 43 317.220 337.728 557.559 351.012   13.800        1
# 44 317.220 351.528 344.214 364.812    0.000        1
# 45 355.993 351.528 368.987 364.812    0.000        1
# 46 380.766 351.528 428.083 364.812    0.000        1
# 47 439.863 351.528 487.798 364.812    0.000        1
# 48 499.558 351.528 557.474 364.812   13.800        1
# 49 317.220 365.328 557.591 378.612   13.800        1
# 50 317.220 379.128 557.592 392.412   13.800        1
# 51 317.220 392.928 557.527 406.212   13.800        1
# 52 317.220 406.728 557.628 420.012   13.800        1
# 53 317.220 420.528 557.604 433.812   13.800        1
# 54 317.220 434.328 386.242 447.612  -82.800        1
# 55  56.700 351.528 295.331 364.812   13.800        2
# 56  56.700 365.328 295.328 378.612   13.800        2
# 57  56.700 379.128 295.375 392.412   13.800        1
# 58  56.700 392.928 295.381 406.212   13.800        1
# 59  56.700 406.728 295.366 420.012   13.800        1
# 60  56.700 420.528 295.454 433.812   13.800        1
# 61  56.700 434.328 289.931 447.612   21.189        1
# 62  72.660 455.517 548.145 467.671      NaN        2
#
#                                             font_list        common_font  \
# 0                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 1                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 2                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 3                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 4   [TimesNewRomanPSMT, TimesNewRomanPS-ItalicMT, ...    TimesNewRomanPS
# 5                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 6                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 7                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 8                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 9                                 [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 10                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 11                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 12                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 13                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 14                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 15                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 16                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 17                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 18                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 19                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 20                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 21                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 22                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 23                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 24                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 25                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 26                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 27                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 28                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 29                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 30                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 31                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 32                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 33                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 34                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 35                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 36                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 37                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 38                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 39                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 40                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 41                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 42                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 43                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 44                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 45                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 46                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 47                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 48                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 49                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 50                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 51                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 52                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 53                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 54                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 55      [TimesNewRomanPSMT, TimesNewRomanPS-ItalicMT]    TimesNewRomanPS
# 56      [TimesNewRomanPS-ItalicMT, TimesNewRomanPSMT]    TimesNewRomanPS
# 57                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 58                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 59                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 60                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 61                                [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 62      [TimesNewRomanPS-ItalicMT, TimesNewRomanPSMT]    TimesNewRomanPS
#
#                    mode_font  n_words       w      h  \
# 0          TimesNewRomanPSMT       11 238.658 13.284
# 1          TimesNewRomanPSMT        7 238.682 13.284
# 2          TimesNewRomanPSMT        9 238.627 13.284
# 3          TimesNewRomanPSMT        8 238.643 13.284
# 4   TimesNewRomanPS-ItalicMT        8 238.642 13.284
# 5          TimesNewRomanPSMT        8 238.658 13.284
# 6          TimesNewRomanPSMT        8 238.721 13.284
# 7          TimesNewRomanPSMT       10 238.632 13.284
# 8          TimesNewRomanPSMT        7 238.646 13.284
# 9          TimesNewRomanPSMT        7 238.668 13.284
# 10         TimesNewRomanPSMT        9 238.596 13.284
# 11         TimesNewRomanPSMT        9 238.639 13.284
# 12         TimesNewRomanPSMT        7 238.632 13.284
# 13         TimesNewRomanPSMT        9 238.626 13.284
# 14         TimesNewRomanPSMT        9 238.651 13.284
# 15         TimesNewRomanPSMT        8 238.692 13.284
# 16         TimesNewRomanPSMT        6 238.618 13.284
# 17         TimesNewRomanPSMT        8 238.603 13.284
# 18         TimesNewRomanPSMT        9 238.661 13.284
# 19         TimesNewRomanPSMT        8 238.670 13.284
# 20         TimesNewRomanPSMT        7 238.648 13.284
# 21         TimesNewRomanPSMT        8 213.307 13.284
# 22         TimesNewRomanPSMT       10 240.360 13.284
# 23         TimesNewRomanPSMT        8 240.331 13.284
# 24         TimesNewRomanPSMT        9 240.382 13.284
# 25         TimesNewRomanPSMT        9 240.425 13.284
# 26         TimesNewRomanPSMT        9 240.377 13.284
# 27         TimesNewRomanPSMT        9 240.389 13.284
# 28         TimesNewRomanPSMT        7 240.403 13.284
# 29         TimesNewRomanPSMT        9 240.410 13.284
# 30         TimesNewRomanPSMT        8 240.328 13.284
# 31         TimesNewRomanPSMT        7 240.374 13.284
# 32         TimesNewRomanPSMT        7 240.396 13.284
# 33         TimesNewRomanPSMT        7 240.377 13.284
# 34         TimesNewRomanPSMT        8 240.461 13.284
# 35         TimesNewRomanPSMT       11 240.390 13.284
# 36         TimesNewRomanPSMT        8 240.375 13.284
# 37         TimesNewRomanPSMT        7 240.363 13.284
# 38         TimesNewRomanPSMT        6 237.408 13.284
# 39         TimesNewRomanPSMT        2  84.966 13.284
# 40         TimesNewRomanPSMT        8 240.354 13.284
# 41         TimesNewRomanPSMT        9 240.394 13.284
# 42         TimesNewRomanPSMT        7 240.391 13.284
# 43         TimesNewRomanPSMT        8 240.339 13.284
# 44         TimesNewRomanPSMT        1  26.994 13.284
# 45         TimesNewRomanPSMT        1  12.994 13.284
# 46         TimesNewRomanPSMT        1  47.317 13.284
# 47         TimesNewRomanPSMT        1  47.935 13.284
# 48         TimesNewRomanPSMT        1  57.917 13.284
# 49         TimesNewRomanPSMT        7 240.371 13.284
# 50         TimesNewRomanPSMT        7 240.372 13.284
# 51         TimesNewRomanPSMT        8 240.307 13.284
# 52         TimesNewRomanPSMT        9 240.408 13.284
# 53         TimesNewRomanPSMT        8 240.384 13.284
# 54         TimesNewRomanPSMT        3  69.022 13.284
# 55         TimesNewRomanPSMT       11 238.631 13.284
# 56  TimesNewRomanPS-ItalicMT        8 238.628 13.284
# 57         TimesNewRomanPSMT        7 238.675 13.284
# 58         TimesNewRomanPSMT        5 238.681 13.284
# 59         TimesNewRomanPSMT        8 238.666 13.284
# 60         TimesNewRomanPSMT        7 238.754 13.284
# 61         TimesNewRomanPSMT        9 233.231 13.284
# 62  TimesNewRomanPS-ItalicMT       16 475.485 12.155
#
#                                                  text  \
# 0      It was June 2012, and I had come to the Globe
# 1         Theatre in London.  The company was called
# 2         Rah-e-Sabz (‘Path to Hope’), and they were
# 3     from Afghanistan; they were about to perform a
# 4    version of The Comedy of Errors translated into
# 5            Persian as part of a festival of global
# 6      Shakespeare.  This play was a brave choice as
# 7   the text is a notoriously tall order.  Two set...
# 8   identical twins (two masters, two servants) find
# 9     themselves separated by a shipwreck.  One pair
# 10   end up in Ephesus (in present-day Turkey) – set
# 11   up home, settle down.  Little do they know that
# 12         their brothers have set off from Syracuse
# 13   (present-day Sicily) in search of them and have
# 14  just arrived in town. For the Sicilian twins all
# 15     hell breaks loose: people they have never met
# 16     keep recognising them, mysterious women sidle
# 17  up, claiming to share intimate histories.  For...
# 18     Turkish ones, it’s nearly as bad: everyone in
# 19      town suddenly seems to have gone crazy.  Not
# 20  realising they are constantly being mistaken for
# 21    their twins, all four fear they are bewitched.
# 22        but it had escaped me how much it dwelt on
# 23  exile and separation.  I’d forgotten altogethe...
# 24   character of Egeon, father to two of the twins,
# 25    who prior to the action has been searching the
# 26  world for five years, frantic to find his absent
# 27    sons.  He also arrives in Ephesus/Kabul and is
# 28  brusquely arrested for being an illegal immigr...
# 29     and then placed on death row. There was farce
# 30   aplenty, a joyous amount of yelling and chasing
# 31          around with brooms, but much else seemed
# 32     fraught.  The visiting twins were required to
# 33   swap clothes – something that produced hoots in
# 34  the audience but also had the sinister implica...
# 35  that it was too dangerous to stay as they were...
# 36         was an example of how Shakespeare’s plays
# 37      could take root in places geographically and
# 38      ideologically remote from those of sixteenth-
# 39                                  century England.
# 40        As we worked towards the conclusion of the
# 41  play, as father and brothers separated for so ...
# 42  hugged each other disbelievingly, it occurred to
# 43      me that there was something else, too.  This
# 44                                             story
# 45                                                of
# 46                                         journeys,
# 47                                         mistakes,
# 48                                       confusions,
# 49   misplaced identities – being in a strange land,
# 50        trying to know and comprehend its culture,
# 51          finding both less and more than you ever
# 52  imagined – asked a question that lay at the root
# 53  of global Shakespeare.  What does it really feel
# 54                                   like to travel?
# 55  For most of its history on stage in the west, ...
# 56          Comedy of Errors has been dismissed as a
# 57     creaky and mechanistic farce with its rampant
# 58  improbabilities, Elizabethan wordplay, its corny
# 59    sight gags.  But as I watched the performance,
# 60        set in contemporary Kabul, I saw something
# 61   quite new.  The word “comedy” was in the title
# 62  These texts have been adapted, for the purpose...
#
#                                   font_sizes  font_size
# 0                                     [12.0]     12.000
# 1                                     [12.0]     12.000
# 2                                     [12.0]     12.000
# 3                                     [12.0]     12.000
# 4                         [12.0, 12.0, 12.0]     12.000
# 5                                     [12.0]     12.000
# 6                                     [12.0]     12.000
# 7                                     [12.0]     12.000
# 8                                     [12.0]     12.000
# 9                                     [12.0]     12.000
# 10                                    [12.0]     12.000
# 11                                    [12.0]     12.000
# 12                                    [12.0]     12.000
# 13                                    [12.0]     12.000
# 14                                    [12.0]     12.000
# 15                                    [12.0]     12.000
# 16                                    [12.0]     12.000
# 17                                    [12.0]     12.000
# 18                                    [12.0]     12.000
# 19                                    [12.0]     12.000
# 20                                    [12.0]     12.000
# 21                                    [12.0]     12.000
# 22                                    [12.0]     12.000
# 23                                    [12.0]     12.000
# 24                                    [12.0]     12.000
# 25                                    [12.0]     12.000
# 26                                    [12.0]     12.000
# 27                                    [12.0]     12.000
# 28                                    [12.0]     12.000
# 29                                    [12.0]     12.000
# 30                                    [12.0]     12.000
# 31                                    [12.0]     12.000
# 32                                    [12.0]     12.000
# 33                                    [12.0]     12.000
# 34                                    [12.0]     12.000
# 35                                    [12.0]     12.000
# 36                                    [12.0]     12.000
# 37                                    [12.0]     12.000
# 38                                    [12.0]     12.000
# 39                                    [12.0]     12.000
# 40                                    [12.0]     12.000
# 41                                    [12.0]     12.000
# 42                                    [12.0]     12.000
# 43                                    [12.0]     12.000
# 44                                    [12.0]     12.000
# 45                                    [12.0]     12.000
# 46                                    [12.0]     12.000
# 47                                    [12.0]     12.000
# 48                                    [12.0]     12.000
# 49                                    [12.0]     12.000
# 50                                    [12.0]     12.000
# 51                                    [12.0]     12.000
# 52                                    [12.0]     12.000
# 53                                    [12.0]     12.000
# 54                                    [12.0]     12.000
# 55                              [12.0, 12.0]     12.000
# 56                              [12.0, 12.0]     12.000
# 57                                    [12.0]     12.000
# 58                                    [12.0]     12.000
# 59                                    [12.0]     12.000
# 60                                    [12.0]     12.000
# 61                                    [12.0]     12.000
# 62  [10.979999542236328, 10.020000457763672]     10.020

# %%
pd.set_option('display.max_rows', None)
pink_df.x0 = pink_df.x0.map(lambda x: round(x))
pink_df.x1 = pink_df.x1.map(lambda x: round(x))
pink_df.y0 = pink_df.y0.map(lambda y: round(y))
pink_df.y1 = pink_df.y1.map(lambda y: round(y))
display(pink_df[["x0","x1","y0","y1","common_font", "n_words"]])
# Out:
#      x0   x1   y0   y1        common_font  n_words
# 0    57  295   34   47  TimesNewRomanPSMT       11
# 1    57  295   48   61  TimesNewRomanPSMT        7
# 2    57  295   62   75  TimesNewRomanPSMT        9
# 3    57  295   76   89  TimesNewRomanPSMT        8
# 4    57  295   89  103    TimesNewRomanPS        8
# 5    57  295  103  116  TimesNewRomanPSMT        8
# 6    57  295  117  130  TimesNewRomanPSMT        8
# 7    57  295  131  144  TimesNewRomanPSMT       10
# 8    57  295  145  158  TimesNewRomanPSMT        7
# 9    57  295  158  172  TimesNewRomanPSMT        7
# 10   57  295  172  185  TimesNewRomanPSMT        9
# 11   57  295  186  199  TimesNewRomanPSMT        9
# 12   57  295  200  213  TimesNewRomanPSMT        7
# 13   57  295  214  227  TimesNewRomanPSMT        9
# 14   57  295  227  241  TimesNewRomanPSMT        9
# 15   57  295  241  254  TimesNewRomanPSMT        8
# 16   57  295  255  268  TimesNewRomanPSMT        6
# 17   57  295  269  282  TimesNewRomanPSMT        8
# 18   57  295  283  296  TimesNewRomanPSMT        9
# 19   57  295  296  310  TimesNewRomanPSMT        8
# 20   57  295  310  323  TimesNewRomanPSMT        7
# 21   57  270  324  337  TimesNewRomanPSMT        8
# 22  317  558   34   47  TimesNewRomanPSMT       10
# 23  317  558   48   61  TimesNewRomanPSMT        8
# 24  317  558   62   75  TimesNewRomanPSMT        9
# 25  317  558   76   89  TimesNewRomanPSMT        9
# 26  317  558   89  103  TimesNewRomanPSMT        9
# 27  317  558  103  116  TimesNewRomanPSMT        9
# 28  317  558  117  130  TimesNewRomanPSMT        7
# 29  317  558  131  144  TimesNewRomanPSMT        9
# 30  317  558  145  158  TimesNewRomanPSMT        8
# 31  317  558  158  172  TimesNewRomanPSMT        7
# 32  317  558  172  185  TimesNewRomanPSMT        7
# 33  317  558  186  199  TimesNewRomanPSMT        7
# 34  317  558  200  213  TimesNewRomanPSMT        8
# 35  317  558  214  227  TimesNewRomanPSMT       11
# 36  317  558  227  241  TimesNewRomanPSMT        8
# 37  317  558  241  254  TimesNewRomanPSMT        7
# 38  317  555  255  268  TimesNewRomanPSMT        6
# 39  317  402  269  282  TimesNewRomanPSMT        2
# 40  317  558  296  310  TimesNewRomanPSMT        8
# 41  317  558  310  323  TimesNewRomanPSMT        9
# 42  317  558  324  337  TimesNewRomanPSMT        7
# 43  317  558  338  351  TimesNewRomanPSMT        8
# 44  317  344  352  365  TimesNewRomanPSMT        1
# 45  356  369  352  365  TimesNewRomanPSMT        1
# 46  381  428  352  365  TimesNewRomanPSMT        1
# 47  440  488  352  365  TimesNewRomanPSMT        1
# 48  500  557  352  365  TimesNewRomanPSMT        1
# 49  317  558  365  379  TimesNewRomanPSMT        7
# 50  317  558  379  392  TimesNewRomanPSMT        7
# 51  317  558  393  406  TimesNewRomanPSMT        8
# 52  317  558  407  420  TimesNewRomanPSMT        9
# 53  317  558  421  434  TimesNewRomanPSMT        8
# 54  317  386  434  448  TimesNewRomanPSMT        3
# 55   57  295  352  365    TimesNewRomanPS       11
# 56   57  295  365  379    TimesNewRomanPS        8
# 57   57  295  379  392  TimesNewRomanPSMT        7
# 58   57  295  393  406  TimesNewRomanPSMT        5
# 59   57  295  407  420  TimesNewRomanPSMT        8
# 60   57  295  421  434  TimesNewRomanPSMT        7
# 61   57  290  434  448  TimesNewRomanPSMT        9
# 62   73  548  456  468    TimesNewRomanPS       16

# %%
pink_df.iloc[50:61]
# Out:
#      x0   y0   x1   y1      dL  n_spans  \
# 50  317  379  558  392  13.800        1
# 51  317  393  558  406  13.800        1
# 52  317  407  558  420  13.800        1
# 53  317  421  558  434  13.800        1
# 54  317  434  386  448 -82.800        1
# 55   57  352  295  365  13.800        2
# 56   57  365  295  379  13.800        2
# 57   57  379  295  392  13.800        1
# 58   57  393  295  406  13.800        1
# 59   57  407  295  420  13.800        1
# 60   57  421  295  434  13.800        1
#
#                                         font_list        common_font  \
# 50                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 51                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 52                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 53                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 54                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 55  [TimesNewRomanPSMT, TimesNewRomanPS-ItalicMT]    TimesNewRomanPS
# 56  [TimesNewRomanPS-ItalicMT, TimesNewRomanPSMT]    TimesNewRomanPS
# 57                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 58                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 59                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 60                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
#
#                    mode_font  n_words       w      h  \
# 50         TimesNewRomanPSMT        7 240.372 13.284
# 51         TimesNewRomanPSMT        8 240.307 13.284
# 52         TimesNewRomanPSMT        9 240.408 13.284
# 53         TimesNewRomanPSMT        8 240.384 13.284
# 54         TimesNewRomanPSMT        3  69.022 13.284
# 55         TimesNewRomanPSMT       11 238.631 13.284
# 56  TimesNewRomanPS-ItalicMT        8 238.628 13.284
# 57         TimesNewRomanPSMT        7 238.675 13.284
# 58         TimesNewRomanPSMT        5 238.681 13.284
# 59         TimesNewRomanPSMT        8 238.666 13.284
# 60         TimesNewRomanPSMT        7 238.754 13.284
#
#                                                  text    font_sizes  font_size
# 50        trying to know and comprehend its culture,         [12.0]     12.000
# 51          finding both less and more than you ever         [12.0]     12.000
# 52  imagined – asked a question that lay at the root         [12.0]     12.000
# 53  of global Shakespeare.  What does it really feel         [12.0]     12.000
# 54                                   like to travel?         [12.0]     12.000
# 55  For most of its history on stage in the west, ...  [12.0, 12.0]     12.000
# 56          Comedy of Errors has been dismissed as a   [12.0, 12.0]     12.000
# 57     creaky and mechanistic farce with its rampant         [12.0]     12.000
# 58  improbabilities, Elizabethan wordplay, its corny         [12.0]     12.000
# 59    sight gags.  But as I watched the performance,         [12.0]     12.000
# 60        set in contemporary Kabul, I saw something         [12.0]     12.000

# %%
pink_df.x0.value_counts()
# Out:
# x0
# 57     29
# 317    29
# 356     1
# 381     1
# 440     1
# 500     1
# 73      1
# Name: count, dtype: int64

# %%
pink_df[pink_df.x0.isin([73, 500, 440, 381, 356])]
# Out:
#      x0   y0   x1   y1     dL  n_spans  \
# 45  356  352  369  365  0.000        1
# 46  381  352  428  365  0.000        1
# 47  440  352  488  365  0.000        1
# 48  500  352  557  365 13.800        1
# 62   73  456  548  468    NaN        2
#
#                                         font_list        common_font  \
# 45                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 46                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 47                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 48                            [TimesNewRomanPSMT]  TimesNewRomanPSMT
# 62  [TimesNewRomanPS-ItalicMT, TimesNewRomanPSMT]    TimesNewRomanPS
#
#                    mode_font  n_words       w      h  \
# 45         TimesNewRomanPSMT        1  12.994 13.284
# 46         TimesNewRomanPSMT        1  47.317 13.284
# 47         TimesNewRomanPSMT        1  47.935 13.284
# 48         TimesNewRomanPSMT        1  57.917 13.284
# 62  TimesNewRomanPS-ItalicMT       16 475.485 12.155
#
#                                                  text  \
# 45                                                of
# 46                                         journeys,
# 47                                         mistakes,
# 48                                       confusions,
# 62  These texts have been adapted, for the purpose...
#
#                                   font_sizes  font_size
# 45                                    [12.0]     12.000
# 46                                    [12.0]     12.000
# 47                                    [12.0]     12.000
# 48                                    [12.0]     12.000
# 62  [10.979999542236328, 10.020000457763672]     10.020

# %%
pink_df.x1.value_counts()
# Out:
# x1
# 295    27
# 558    25
# 270     1
# 555     1
# 402     1
# 344     1
# 369     1
# 428     1
# 488     1
# 557     1
# 386     1
# 290     1
# 548     1
# Name: count, dtype: int64

# %% [markdown]
# # Definition of column boundaries

# %% [markdown]
# This will be a combination of b1=(x00, x01) and b2=(x10,x11) pairs. Between x01 and x10, there is a strip of emmpty
# space within the pink bounding box.

# %% [markdown]
# This is a boundary within which:
# - All the text will have the standard font size (the mode fontsize over the last several pages)
# - The majority of the text will have the standard font type (the mode font type over the last few pages)
# - The majority of text is bound.

# %% [markdown]
# # Dual column line properties
# - In the pink
# - Correct font size
# - does not cross centre line. (does not start or stop in centre line.)
# - below certain width
# - at least one line above or below which is also a column line (unless it is the first line of a new page with nothing below)
# - Second column to the right or left, which shares a y0 and y1.
#
# Note for this to work all lines must be lines. Single words separated out from the line in which they occur will disrupt
# the choosing of x0's as you can see above.
